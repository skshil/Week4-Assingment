# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### __Saikat Kumar Shil__
# I want to persue Data Scientist as my career

# %% [markdown]
# *I am interested in data science because I love numbers and the data makes me curious. my first encounter with data science was when a mentor shared a story about how Asian Paint, an Indian paint company used data to optimize its operation. This forced me to think about what else we can be done, and after I researched I became more hooked on the subject of Data Science. My first course was Google analytics, and it was amazing how we could make complicated numbers into very easy graphs and pie charts. Being a Data Scientist will not only allow me to fulfill my dreams but also give me the power to help this world solve complicated problems and be a valuable member of the society I live.*

# %% [markdown]
# ### The code below will add 2 variables to get an answer

# %%
a = 5
b = 10
print(a+b)
# Out:
# 15

# %% [markdown]
# ![Jupyter_main.png](attachment:71a8adc0-4dc1-4b4e-8852-922f91f7c029.png)
# # [ Above is a Juypter notebook image](https://jupyter.org/)
#
#  - Bullet Points
#     - Bullet Points
#       - Bullet Points
#         - Bullet Points
